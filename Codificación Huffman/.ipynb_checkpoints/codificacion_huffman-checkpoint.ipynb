# %%
import numpy as np

probabilidad_letra = {'a': None, 'b': None, 'c': None, 'd': None, 'e': None, 'f': None, 'g': None,
                      'h': None, 'i': None, 'j': None, 'k': None, 'l': None, 'm': None, 'n': None,
                      'ñ': None, 'o': None, 'p': None, 'q': None, 'r': None, 's': None, 't': None,
                      'u': None, 'v': None, 'w': None, 'x': None, 'y': None, 'z': None}

print('Cantidad de letras:', len(probabilidad_letra.keys()))

# Generar una lista de 27 números aleatorios entre 0 y 1
random_numbers = np.random.rand(27)

# Normalizar la lista para que la suma sea igual a 1
normalized_numbers = random_numbers / sum(random_numbers)

list_claves = list(probabilidad_letra.keys())

# Agregar las probabilidades al diccionario
for i in range(len(list_claves)):
  probabilidad_letra[list_claves[i]] = normalized_numbers[i]

for c, v in probabilidad_letra.items():
  print(c, v)

print('\nSuma de las probabilidades:', sum(probabilidad_letra.values()))
# Out:
# Cantidad de letras: 27
# a 0.05403498435202303
# b 0.005818847563738379
# c 0.045445068442132086
# d 0.07224294225821225
# e 0.04251672088741277
# f 0.0349104545081314
# g 0.04888495765199854
# h 0.024831612465151604
# i 0.029323426065155072
# j 0.025834550051790417
# k 0.01023746237555228
# l 0.06693971606395
# m 0.008343395498631114
# n 0.00018405574758204268
# ñ 0.002657591456242626
# o 0.027080483663454506
# p 0.05780943792540197
# q 0.007831657989195443
# r 0.0151363180933516
# s 0.047334832426678
# t 0.05522042477527388
# u 0.04281971214211256
# v 0.03156861767766744
# w 0.07171683192323501
# x 0.08015235007225288
# y 0.07727320119758332
# z 0.013850346726089676
#
# Suma de las probabilidades: 0.9999999999999998

# %%
# Ordenar las letras en funcíon de la probabilidad asignada
import pandas as pd

pd.set_option('display.max_columns', None)

df = pd.DataFrame(probabilidad_letra, index=['P0'])
df_transpuesta = df.transpose()
df_sorted = df_transpuesta.sort_values(by='P0', ascending=False)
df_sorted
# Out:
#          P0
# x  0.080152
# y  0.077273
# d  0.072243
# w  0.071717
# l  0.066940
# p  0.057809
# t  0.055220
# a  0.054035
# g  0.048885
# s  0.047335
# c  0.045445
# u  0.042820
# e  0.042517
# f  0.034910
# v  0.031569
# i  0.029323
# o  0.027080
# j  0.025835
# h  0.024832
# r  0.015136
# z  0.013850
# k  0.010237
# m  0.008343
# q  0.007832
# b  0.005819
# ñ  0.002658
# n  0.000184

# %%
def asignar_bits(x, bit):
  print(x)

# Lista con los número del 0 al 27 (No incluye el 27)
bits = list(range(df_sorted['P0'].count()-1))

for i_bit in range(len(bits)):
  # Asignar los bits 0 y 1 a las últimas posiciones de cada columna en cada iteración
  df_sorted[f'Bit {i_bit}'] = df_sorted['P0'].apply(lambda x: 1 if df_sorted['P0'].iloc[-(i_bit+1)]==x
                                                           else (0 if df_sorted['P0'].iloc[-(i_bit+2)]==x else '-'))

  # Sumar las posiciones donde se encuentran las bits 0 y 1
  suma_ultimas_2_posciones = df_sorted['P0'][(df_sorted[f'Bit {i_bit}']==1) | (df_sorted[f'Bit {i_bit}']==0)].sum()
  print(suma_ultimas_2_posciones)

  # Crear las nuevas probabilidades
  if i_bit < len(bits)-1:
    

    def asignar_probabilidad(x):
      if x > suma_ultimas_2_posciones:
        return x

      elif x <= suma_ultimas_2_posciones:
        if x == suma_ultimas_2_posciones:
          return suma_ultimas_2_posciones

        else:
          return 0

    df_sorted[f'P{i_bit+1}'] = df_sorted[f'P{i_bit}'].apply(lambda x: asignar_probabilidad(x))

df_sorted
# Out:
# 0.0028416472038246686
# 0.008476439019981005
# 0.013650505552933822
# 0.01617505348782656
# 0.01858085787418339
# 0.024087809101641953
# 0.028986664819441274
# 0.0399679305585032
# 0.05066616251694202
# 0.05291503371524492
# 0.05640390972860958
# 0.06089204374282252
# 0.06647907218579885
# 0.07742717539554417
# 0.08533643302952533
# 0.08826478058424464
# 0.09277990086881008
# 0.09621979007867654
# 0.10291994200402158
# 0.1092554091272969
# 0.11302986270067585
# 0.12474915398935196
# 0.13865654798718502
# 0.14395977418144726
# 0.14951614345579556
# 0.1574255512698362
#          P0 Bit 0        P1 Bit 1        P2 Bit 2        P3 Bit 3        P4  \
# x  0.080152     -  0.080152     -  0.080152     -  0.080152     -  0.080152
# y  0.077273     -  0.077273     -  0.077273     -  0.077273     -  0.077273
# d  0.072243     -  0.072243     -  0.072243     -  0.072243     -  0.072243
# w  0.071717     -  0.071717     -  0.071717     -  0.071717     -  0.071717
# l  0.066940     -  0.066940     -  0.066940     -  0.066940     -  0.066940
# p  0.057809     -  0.057809     -  0.057809     -  0.057809     -  0.057809
# t  0.055220     -  0.055220     -  0.055220     -  0.055220     -  0.055220
# a  0.054035     -  0.054035     -  0.054035     -  0.054035     -  0.054035
# g  0.048885     -  0.048885     -  0.048885     -  0.048885     -  0.048885
# s  0.047335     -  0.047335     -  0.047335     -  0.047335     -  0.047335
# c  0.045445     -  0.045445     -  0.045445     -  0.045445     -  0.045445
# u  0.042820     -  0.042820     -  0.042820     -  0.042820     -  0.042820
# e  0.042517     -  0.042517     -  0.042517     -  0.042517     -  0.042517
# f  0.034910     -  0.034910     -  0.034910     -  0.034910     -  0.034910
# v  0.031569     -  0.031569     -  0.031569     -  0.031569     -  0.031569
# i  0.029323     -  0.029323     -  0.029323     -  0.029323     -  0.029323
# o  0.027080     -  0.027080     -  0.027080     -  0.027080     -  0.027080
# j  0.025835     -  0.025835     -  0.025835     -  0.025835     -  0.025835
# h  0.024832     -  0.024832     -  0.024832     -  0.024832     -  0.024832
# r  0.015136     -  0.015136     -  0.015136     -  0.015136     -  0.000000
# z  0.013850     -  0.013850     -  0.013850     -  0.013850     -  0.000000
# k  0.010237     -  0.010237     -  0.010237     -  0.000000     -  0.000000
# m  0.008343     -  0.008343     -  0.000000     -  0.000000     0  0.000000
# q  0.007832     -  0.007832     -  0.000000     0  0.000000     1  0.000000
# b  0.005819     -  0.005819     0  0.000000     1  0.000000     -  0.000000
# ñ  0.002658     0  0.000000     1  0.000000     -  0.000000     -  0.000000
# n  0.000184     1  0.000000     -  0.000000     -  0.000000     -  0.000000
#
#   Bit 4        P5 Bit 5        P6 Bit 6        P7 Bit 7        P8 Bit 8  \
# x     -  0.080152     -  0.080152     -  0.080152     -  0.080152     -
# y     -  0.077273     -  0.077273     -  0.077273     -  0.077273     -
# d     -  0.072243     -  0.072243     -  0.072243     -  0.072243     -
# w     -  0.071717     -  0.071717     -  0.071717     -  0.071717     -
# l     -  0.066940     -  0.066940     -  0.066940     -  0.066940     -
# p     -  0.057809     -  0.057809     -  0.057809     -  0.057809     -
# t     -  0.055220     -  0.055220     -  0.055220     -  0.055220     -
# a     -  0.054035     -  0.054035     -  0.054035     -  0.054035     -
# g     -  0.048885     -  0.048885     -  0.048885     -  0.048885     -
# s     -  0.047335     -  0.047335     -  0.047335     -  0.047335     -
# c     -  0.045445     -  0.045445     -  0.045445     -  0.045445     -
# u     -  0.042820     -  0.042820     -  0.042820     -  0.042820     -
# e     -  0.042517     -  0.042517     -  0.042517     -  0.042517     -
# f     -  0.034910     -  0.034910     -  0.034910     -  0.000000     -
# v     -  0.031569     -  0.031569     -  0.031569     -  0.000000     -
# i     -  0.029323     -  0.029323     -  0.029323     -  0.000000     -
# o     -  0.027080     -  0.027080     -  0.000000     -  0.000000     -
# j     -  0.025835     -  0.025835     -  0.000000     -  0.000000     0
# h     -  0.024832     -  0.024832     -  0.000000     0  0.000000     1
# r     -  0.000000     -  0.000000     0  0.000000     1  0.000000     -
# z     -  0.000000     0  0.000000     1  0.000000     -  0.000000     -
# k     0  0.000000     1  0.000000     -  0.000000     -  0.000000     -
# m     1  0.000000     -  0.000000     -  0.000000     -  0.000000     -
# q     -  0.000000     -  0.000000     -  0.000000     -  0.000000     -
# b     -  0.000000     -  0.000000     -  0.000000     -  0.000000     -
# ñ     -  0.000000     -  0.000000     -  0.000000     -  0.000000     -
# n     -  0.000000     -  0.000000     -  0.000000     -  0.000000     -
#
#          P9 Bit 9       P10 Bit 10       P11 Bit 11       P12 Bit 12  \
# x  0.080152     -  0.080152      -  0.080152      -  0.080152      -
# y  0.077273     -  0.077273      -  0.077273      -  0.077273      -
# d  0.072243     -  0.072243      -  0.072243      -  0.072243      -
# w  0.071717     -  0.071717      -  0.071717      -  0.071717      -
# l  0.066940     -  0.066940      -  0.066940      -  0.066940      -
# p  0.057809     -  0.057809      -  0.057809      -  0.000000      -
# t  0.055220     -  0.055220      -  0.000000      -  0.000000      -
# a  0.054035     -  0.054035      -  0.000000      -  0.000000      -
# g  0.000000     -  0.000000      -  0.000000      -  0.000000      -
# s  0.000000     -  0.000000      -  0.000000      -  0.000000      -
# c  0.000000     -  0.000000      -  0.000000      -  0.000000      -
# u  0.000000     -  0.000000      -  0.000000      -  0.000000      -
# e  0.000000     -  0.000000      -  0.000000      -  0.000000      -
# f  0.000000     -  0.000000      -  0.000000      -  0.000000      0
# v  0.000000     -  0.000000      -  0.000000      0  0.000000      1
# i  0.000000     -  0.000000      0  0.000000      1  0.000000      -
# o  0.000000     0  0.000000      1  0.000000      -  0.000000      -
# j  0.000000     1  0.000000      -  0.000000      -  0.000000      -
# h  0.000000     -  0.000000      -  0.000000      -  0.000000      -
# r  0.000000     -  0.000000      -  0.000000      -  0.000000      -
# z  0.000000     -  0.000000      -  0.000000      -  0.000000      -
# k  0.000000     -  0.000000      -  0.000000      -  0.000000      -
# m  0.000000     -  0.000000      -  0.000000      -  0.000000      -
# q  0.000000     -  0.000000      -  0.000000      -  0.000000      -
# b  0.000000     -  0.000000      -  0.000000      -  0.000000      -
# ñ  0.000000     -  0.000000      -  0.000000      -  0.000000      -
# n  0.000000     -  0.000000      -  0.000000      -  0.000000      -
#
#         P13 Bit 13       P14 Bit 14  P15 Bit 15  P16 Bit 16  P17 Bit 17  P18  \
# x  0.080152      -  0.080152      -    0      -    0      -    0      -    0
# y  0.077273      -  0.000000      -    0      -    0      -    0      -    0
# d  0.072243      -  0.000000      -    0      -    0      -    0      -    0
# w  0.071717      -  0.000000      -    0      -    0      -    0      -    0
# l  0.066940      -  0.000000      -    0      -    0      -    0      -    0
# p  0.000000      -  0.000000      -    0      -    0      -    0      -    0
# t  0.000000      -  0.000000      -    0      -    0      -    0      -    0
# a  0.000000      -  0.000000      -    0      -    0      -    0      -    0
